# %%
import os
import pandas as pd

#### GET ALL DATA FROM CSV
df = pd.read_csv(
    "csv/df_table_all_datas.csv",
    parse_dates=["Date_monthly"]
)
df.head(200)
# Out:
#     Date_monthly  gazole_eur_liter_htt  gazole_eur_liter_ttc  \
# 0     2015-01-01                0.4484                1.1149
# 1     2015-02-01                0.5081                1.1865
# 2     2015-03-01                0.5251                1.2069
# 3     2015-04-01                0.5205                1.2014
# 4     2015-05-01                0.5477                1.2341
# ..           ...                   ...                   ...
# 128   2025-09-01                0.7298                1.6067
# 129   2025-10-01                0.7247                1.6006
# 130   2025-11-01                0.7854                1.6735
# 131   2025-12-01                0.7081                1.5808
# 132   2026-01-01                0.7544                1.6344
#
#      brent_gazole_EUR_liter  refining_margin_brent_eur_liter  \
# 0                    0.3223                          0.03633
# 1                    0.3355                          0.03900
# 2                    0.3696                          0.04791
# 3                    0.3674                          0.04180
# 4                    0.4103                          0.03840
# ..                      ...                              ...
# 128                  0.4092                          0.06442
# 129                  0.3850                          0.06136
# 130                  0.3894                          0.08986
# 131                  0.3762                          0.04948
# 132                  0.3575                          0.02701
#
#      Gazole_transportation_fees_eur_liter  calculate_gazole_eur_liter_htt  \
# 0                                   0.086                         0.44463
# 1                                   0.086                         0.46050
# 2                                   0.086                         0.50351
# 3                                   0.086                         0.49520
# 4                                   0.086                         0.53470
# ..                                    ...                             ...
# 128                                 0.219                         0.69262
# 129                                 0.219                         0.66536
# 130                                 0.219                         0.69826
# 131                                 0.219                         0.64468
# 132                                 0.219                         0.60351
#
#      gazole_taxes  gazole_taxes_eur_liter
# 0          0.6665                  0.6665
# 1          0.6784                  0.6784
# 2          0.6818                  0.6818
# 3          0.6809                  0.6809
# 4          0.6864                  0.6864
# ..            ...                     ...
# 128        0.8769                  0.8769
# 129        0.8759                  0.8759
# 130        0.8881                  0.8881
# 131        0.8727                  0.8727
# 132        0.8800                  0.8800
#
# [133 rows x 9 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt

cols_to_stack = [
    'brent_gazole_EUR_liter',
    'refining_margin_brent_eur_liter',
    'Gazole_transportation_fees_eur_liter',
    'gazole_taxes_eur_liter'
]
labels_french = [
    'Brent pondéré pour Gazole (€ / L)',
    'Marge de raffinage (€ / L)',
    'Frais de transport (€ / L)',
    'Taxes et impositions (€ / L)'
]


# Plot
plt.figure(figsize=(12,6))
plt.stackplot(
    df['Date_monthly'], 
    df[cols_to_stack].T,  # Transpose pour stackplot
    labels=labels_french,
    alpha=0.8
)
plt.legend(loc='upper left')
plt.title("Composition du prix du Gazole (€ / litre) - Stacked Area Chart")
plt.ylabel("€/l")
plt.xlabel("Date")
plt.show()
